# %%
import torch
import torch.nn as nn

# se crea la clase MyNetwork(blueprint) y nn.Module tiene todo lo relacionado con neural networks(La base)
# en def __init__(self) se crea la network y se definen los parametros
class MyNetwork(nn.Module)

def __init__(self):
    self.capa1 = nn.Linear(784,128)
    self.capa2 = nn.Linear(128,64)
    self.capa3 = nn.Linear(64,10)
    self.relu = nn.Relu()
# Out:
# MiRed(
#   (capa1): Linear(in_features=784, out_features=128, bias=True)
#   (capa2): Linear(in_features=128, out_features=64, bias=True)
#   (capa3): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
# )
